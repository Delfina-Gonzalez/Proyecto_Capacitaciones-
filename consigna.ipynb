# %% [markdown]
# ## Consignas
#
# 1) Proporcionar el reporte / dashboard según los criterios mencionados.
#     - Para ejecutar el dashboard, se puede correr Streamlit posicionado en la terminar desde la carpeta "case6382", y ejecutar "streamlit run Inicio.py". URL PÚBLICA: https://r74untgmt4wsf9qwaqrz2l.streamlit.app/

# %% [markdown]
# 2) Las tablas provistas se extraen de nuestra base de datos a través de Redash (no es necesario que uses este programa para ninguna consigna de este desafío). El cliente precisa que este reporte esté actualizado todas las semanas, que proponés para esto?
#     - Se propone automatizar la extracción de Redash mediante su API para depositar los archivos directamente en la carpeta /data. El dashboard detectará los nuevos archivos y, con un solo clic en 'Actualizar Datos', procesará la información, generará el histórico y actualizará los KPIs sin intervención manual.

# %% [markdown]
# 3) Mencioná 3 insights que observes del análisis de los resultados respecto a los grupos de segmentación.
#     - Al comparar el último trimestre de 2023 con 2024, se observa un aumento significativo en la cantidad de capacitaciones otorgadas, con un pico notable en marzo de 2024. Casi todos los empleados tomaron los 3 cursos disponibles en Marzo 24. Se puede analizar si esto se debe a programas internos de difusión, incentivos, o la fecha en sí en caso de tener datasets de más períodos.
#     - La información sobre los centros con menor cobertura de capacitaciones es muy valiosa para su análisis, ya que permite focalizar acciones de mejora, capacitaciones dirigidas o incentivos específicos para aumentar la participación en esos grupos o sedes.
#     - La tasa de aprobación es muy alta. Puede ser  Se podría tomar este dato también para evaluar la calidad/nivel de dificultad de las capacitaciones elegidas.
#     - La tasa de aprobación general es muy elevada, lo cual refleja un buen nivel de cumplimiento por parte de los empleados. No obstante, este indicador también puede utilizarse para evaluar la dificultad y profundidad de las capacitaciones ofrecidas(¿son poco desafiantes?).
#     Complementariamente, el análisis de empleados con mayor y menor cantidad de capacitaciones por centro aporta información relevante para los coordinadores de área, permitiendo cruzar estos datos con desempeño u otros indicadores de desempeño. En este sentido, se incorporó la funcionalidad de descarga del listado de empleados sin capacitación por centro, facilitando su seguimiento y comunicación interna.
